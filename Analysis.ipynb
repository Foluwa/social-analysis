# %%
import pandas as pd
from collections import Counter
import re
import pandas as pd
import pymongo

# %%
data = pd.read_csv("GloWorld.csv") 
data
# Out:
#                    USERID         USERNAME USERFOLLOWERS  \
# 0     1238250044727463938      DrScoBrain1           182
# 1     1238246285527977985       Kingrolex1           352
# 2     1238239428746805249       donkamason          1057
# 3     1238238739236782081      DustinM1228           111
# 4     1238238082006167559       ibrahim247           850
# ...                   ...              ...           ...
# 2420  1238273786039984130          GloCare        262937
# 2421  1238273493453725696          GloCare        262937
# 2422  1238273376021553152          GloCare        262937
# 2423  1238271565365760001          GloCare        262937
# 2424  1238257706982690821  ___crackbaybiee           245
#
#                                                    TEXT              CREATED  \
# 0     RT @GloCare: @DrScoBrain1 @GloWorld Hello. We ...  2020-03-12 23:46:30
# 1     @GloWorld why can't I subscribe to the night plan  2020-03-12 23:31:34
# 2     @9mobileng, @GloWorld does Comcast have two he...  2020-03-12 23:04:19
# 3                                    @GloWorld Facebook  2020-03-12 23:01:35
# 4     @GloCare @GloWorld Well she didn't, rather, sh...  2020-03-12 22:58:58
# ...                                                 ...                  ...
# 2420  @Kingrolex1 @GloWorld Hello,have you been able...  2020-03-13 01:20:51
# 2421  @Official_Gboro @GloWorld Kindly send cancel t...  2020-03-13 01:19:41
# 2422  @AdebolaOshin @GloWorld Our tariff for sms is ...  2020-03-13 01:19:13
# 2423  @DrScoBrain1 @GloWorld Hello,the issue has bee...  2020-03-13 01:12:01
# 2424  @GloWorld You guys keep taking my normal data ...  2020-03-13 00:16:57
#
#                  POLARITY        SUBJECTIVITY SENTIMENT
# 0                     0.0                 0.0   NEUTRAL
# 1                     0.0                 0.0   NEUTRAL
# 2                     0.0                 0.0   NEUTRAL
# 3                     0.0                 0.0   NEUTRAL
# 4                     0.0                 0.0   NEUTRAL
# ...                   ...                 ...       ...
# 2420                  0.5               0.625  POSITIVE
# 2421  0.23333333333333334                0.75  POSITIVE
# 2422                  0.0                 0.1   NEUTRAL
# 2423                 -0.5                 1.0  NEGATIVE
# 2424                 0.15  0.6499999999999999  NEGATIVE
#
# [2425 rows x 8 columns]

# %%
DataText=data['TEXT']
# print(DataText)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2425 entries, 0 to 2424
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   USERID         2425 non-null   object
#  1   USERNAME       2425 non-null   object
#  2   USERFOLLOWERS  2425 non-null   object
#  3   TEXT           2425 non-null   object
#  4   CREATED        2425 non-null   object
#  5   POLARITY       2425 non-null   object
#  6   SUBJECTIVITY   2425 non-null   object
#  7   SENTIMENT      2425 non-null   object
# dtypes: object(8)
# memory usage: 151.7+ KB

# %%
# FIND 100 MOST appearing words
monk = Counter(" ".join(DataText).split()).most_common(10)
monk[0][0]
# Out:
# 'to'

# %%
DataCreated = data['CREATED']
DataCreated.head()
#print('*******************************')
# Out:
# 0    2020-03-12 23:46:30
# 1    2020-03-12 23:31:34
# 2    2020-03-12 23:04:19
# 3    2020-03-12 23:01:35
# 4    2020-03-12 22:58:58
# Name: CREATED, dtype: object

# %%
# s = pd.Series(['A', 'B', 'C'])
# for index, value in s.items():
#     print(f"Index : {index}, Value : {value}")
# Index : 0, Value : A
# Index : 1, Value : B
# Index : 2, Value : C
type(DataCreated)
# Out:
# pandas.core.series.Series

# %%
for index, value in DataCreated.size():
    print(f"Index : {index}, Value : {value}")
#     SplitDataCreated = DataCreated[i].split()
#     print(SplitDataCreated[0])
  






# DataCreated.split()



# DataCreated

# print(SplitDataCreated[0])
# print(SplitDataCreated[1])
#data['CREATED'] = SplitDataCreated
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-66355d21703c> in <module>
# ----> 1 for index, value in DataCreated.size():
#       2     print(f"Index : {index}, Value : {value}")
#       3 #     SplitDataCreated = DataCreated[i].split()
#       4 #     print(SplitDataCreated[0])
#       5
#
# TypeError: 'int' object is not callable

# %%
DataText.head()
# Out:
# 0    RT @GloCare: @DrScoBrain1 @GloWorld Hello. We ...
# 1    @GloWorld why can't I subscribe to the night plan
# 2    @9mobileng, @GloWorld does Comcast have two he...
# 3                                   @GloWorld Facebook
# 4    @GloCare @GloWorld Well she didn't, rather, sh...
# Name: TEXT, dtype: object

# %%
adeyefa = pd.read_csv("adeyefa_codes.csv")

# %%
adeyefa.head()
# Out:
#                 USERID       USERNAME  USERFOLLOWERS  \
# 0  1238579993464246272    26th_edmund           2595
# 1  1238577452336721925   wisdomaebong           1451
# 2  1238577224804175874  adeyefa_codes            983
# 3  1238577108764540928  adeyefa_codes            983
# 4  1238576144238198787    26th_edmund           2595
#
#                                                 TEXT              CREATED  \
# 0  @wisdomaebong @adeyefa_codes @hackSultan Cuz n...  2020-03-13 21:37:36
# 1  @26th_edmund @adeyefa_codes @hackSultan We eve...  2020-03-13 21:27:30
# 2  @wisdomaebong @26th_edmund @hackSultan Very te...  2020-03-13 21:26:36
# 3  The dead did not rest in peace https://t.co/Uq...  2020-03-13 21:26:09
# 4  @wisdomaebong @adeyefa_codes @hackSultan Las l...  2020-03-13 21:22:19
#
#    POLARITY  SUBJECTIVITY SENTIMENT
# 0       0.0           0.0   NEUTRAL
# 1       0.0           1.0   NEUTRAL
# 2      -1.0           1.0  NEGATIVE
# 3      -0.2           0.4  NEGATIVE
# 4       0.0           0.0   NEUTRAL

# %%
adeyefa.describe()
# Out:
#              USERID  USERFOLLOWERS   POLARITY  SUBJECTIVITY
# count  6.300000e+01      63.000000  63.000000     63.000000
# mean   1.238447e+18    1754.539683   0.006537      0.124861
# std    8.032948e+13    2509.183306   0.175039      0.271664
# min    1.238257e+18      27.000000  -1.000000      0.000000
# 25%    1.238394e+18     983.000000   0.000000      0.000000
# 50%    1.238449e+18     983.000000   0.000000      0.000000
# 75%    1.238517e+18    1885.500000   0.000000      0.025000
# max    1.238580e+18   19178.000000   0.600000      1.000000

# %%
myclient = pymongo.MongoClient('mongodb+srv://admin:VGoLDnP82lPth3KJ@analysis-vfudj.mongodb.net/test?retryWrites=true&w=majority')
mydatabase = myclient['sentiment_analysis'] # get database
# Check if collection name already exists
mycollection = mydatabase['GloWorld']
try:
    if mycollection in mydatabase.list_collection_names():
        print(mycollection, ' exists in the database.')
    else:
        print(mycollection, ' does not exist in the database.')
        mycollection = mydatabase['GloWorld']
        print("Connected successfully and collection created!!!", mycollection, search_query, mydatabase)
except:
        print("Could not connect to MongoDB")
# Out:
# Collection(Database(MongoClient(host=['analysis-shard-00-00-vfudj.mongodb.net:27017', 'analysis-shard-00-02-vfudj.mongodb.net:27017', 'analysis-shard-00-01-vfudj.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='Analysis-shard-0', ssl=True, retrywrites=True, w='majority'), 'sentiment_analysis'), 'GloWorld')  does not exist in the database.
# Could not connect to MongoDB

# %%
search_query = 'yoruba_dev' #davidoladeji #fantasticfoluwa
myclient = pymongo.MongoClient('mongodb+srv://admin:VGoLDnP82lPth3KJ@analysis-vfudj.mongodb.net/test?retryWrites=true&w=majority')
mydatabase = myclient['sentiment_analysis']  # get database
# Check if collection name already exists
mycollection = mydatabase[search_query]
if mycollection in mydatabase.list_collection_names():
    print(mycollection, ' exists in the database.')
else:
    print(mycollection, ' does not exist in the database.')
    mycollection = mydatabase[search_query]
    print("Connected successfully and collection created!!!", mycollection, search_query, mydatabase)
# Out:
# Collection(Database(MongoClient(host=['analysis-shard-00-01-vfudj.mongodb.net:27017', 'analysis-shard-00-02-vfudj.mongodb.net:27017', 'analysis-shard-00-00-vfudj.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='Analysis-shard-0', ssl=True, retrywrites=True, w='majority'), 'sentiment_analysis'), 'yoruba_dev')  does not exist in the database.
# Connected successfully and collection created!!! Collection(Database(MongoClient(host=['analysis-shard-00-01-vfudj.mongodb.net:27017', 'analysis-shard-00-02-vfudj.mongodb.net:27017', 'analysis-shard-00-00-vfudj.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='Analysis-shard-0', ssl=True, retrywrites=True, w='majority'), 'sentiment_analysis'), 'yoruba_dev') yoruba_dev Database(MongoClient(host=['analysis-shard-00-01-vfudj.mongodb.net:27017', 'analysis-shard-00-02-vfudj.mongodb.net:27017', 'analysis-shard-00-00-vfudj.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='Analysis-shard-0', ssl=True, retrywrites=True, w='majority'), 'sentiment_analysis')

# %%
mycollection = pd.DataFrame(list(mycollection.find()))
mycollection
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-817a3b6299e5> in <module>
# ----> 1 mycollection = pd.DataFrame(list(mycollection.find()))
#       2 mycollection
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'find'

# %%
sentiment_list = mycollection['tweet_sentiment'].value_counts()
print('data frame loaded')
print('My sentiment list is ... ', sentiment_list)
highest_occuring_words = Counter(" ".join(mycollection['tweet_clean']).split()).most_common(10)
print(highest_occuring_words)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'tweet_sentiment'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-ffe1a9d04c83> in <module>
# ----> 1 sentiment_list = mycollection['tweet_sentiment'].value_counts()
#       2 print('data frame loaded')
#       3 print('My sentiment list is ... ', sentiment_list)
#       4 highest_occuring_words = Counter(" ".join(mycollection['tweet_clean']).split()).most_common(10)
#       5 print(highest_occuring_words)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'tweet_sentiment'

# %% [markdown]
# # Real time tweets

# %%
#!/usr/bin/python3
from flask import Flask, request, render_template, jsonify, make_response
from flask_socketio import SocketIO, emit, send
from flask_cors import CORS, cross_origin


# search api
from twitter_scrapper.search_api import TwitterStreamListner
TwitterSearchAPI = TwitterStreamListner()

from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
import re
# streaming api
# from tweepy.streaming import StreamListener
# from twitter_scrapper.streaming_api import StdOutListener

import pandas as pd

import json
from textblob import TextBlob
import eventlet
eventlet.monkey_patch()

# %%
# Enter Twitter API Keys
access_token = "465633653-x7NHimVAVuMGieuVi9GIRFL8TcuCFUxSQ4NjIdHR"
access_token_secret = "hSwFbdEv906tsZ67igSuKXrR8kh3yg1CDg2ElVo9ZO7dK"
consumer_key = "VoPZQmgqLLn9fO3TdSVgdza6q"
consumer_secret = "F1HEnesPeHSn514KYJNRbBFQumbRmrCf74IPsEKXJhIttj3aMT"

# Initialize Global variable
tweet_count = 0
# Input number of tweets to be downloaded
n_tweets = 30000000000

# %%
# STDOUT CLASS
# Create the class that will handle the tweet stream
class StdOutListener(StreamListener):

    def clean_tweet(self, text):
        return ' '.join(re.sub('(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ', text).split().str.lower())

    def on_data(self, data): #change data to tweet
        json_data = json.loads(data)

        # declare pandas dataframe
        df = pd.DataFrame({"cleaned_tweets": []})

        if (not json_data['retweeted']) and ('RT @' not in json_data['text']):
            try:
                global tweet_count
                global n_tweets
                global stream
                if tweet_count < n_tweets:
                    tweet_count +=1
                    created_at = json_data['created_at']
                    text = json_data['text']
                    user = text = json_data['user']['screen_name']

                    # print(' Created At ', created_at )
                    # print( 'Text ', text)
                    # print('User name ', user)
                    # print('TWEET COUNT IS... ', tweet_count)
                    print('________________________________________________________________')

                    print('Data is ... ')
                    #print(json_data)
                    text = json_data['text']
                    #text = re.sub(r'@\S+|https?://\S+', '', text) #clean tweets
                    text = self.clean_tweet(text)
                    #text = text.str.lower()

                    pd_text = text.split(' ')

                    df2 = pd.DataFrame({"cleaned_tweets": [pd_text]})
                    df["cleaned_tweets"] = df["cleaned_tweets"]
                    df.append(df2)

                    print('PANDAS DATAFRAME ... ',df)




                    #print(text)
                    tweet_details = TextBlob(text)

                    # https://textblob.readthedocs.io/en/dev/quickstart.html#sentiment-analysis
                    # Subjective sentences generally refer to personal opinion, emotion or judgment
                    # Objective refers to factual information.
                    if tweet_details.polarity >= 0.2:
                        sentiment = 'POSITIVE'
                    elif tweet_details.polarity == 0:
                        sentiment = 'NEUTRAL'
                    else:
                        sentiment = 'NEGATIVE'

                    with open('tweet.json', 'w') as json_file:
                        json.dump(json_data, json_file)
                    socketio.emit('responseMessage', {'data': text, 'sentiment': sentiment, 'tweet_count': tweet_count,
                                                      'tweet_polarity': tweet_details.polarity,
                                                      'tweet_text': json_data['text'],
                                                      'created_at': json_data['created_at']
                                                      })
                else:
                    stream.disconnect()
                    socketio.emit('responseMessage',  {'data': 'STREAM DISCONNECTED!!'})
                    print('Stream disconnected!')
            except Exception as error:
                print(error)

    def on_error(self, status_code):
        if status_code == 420:
            #returning False in on_data disconnects the stream
            print('Stream disconnected!')
            return False

    # Handles Twitter authentication and the connection to Twitter Streaming API
    def get_search_query(self, search_query):
        print('Inside stream listener ..... ',search_query)
        l = StdOutListener()
        auth = OAuthHandler(consumer_key, consumer_secret)
        auth.set_access_token(access_token, access_token_secret)
        stream = Stream(auth, l)
        stream.filter(track='#COVID19')


# END OF STDOUT CLASS

# %%
import nltk

from nltk.corpus import stopwords

print(stopwords.words('english'))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
from nltk.corpus import stopwords
stoplist = stopwords.words('english')
text = '''
In computing, stop words are words which are filtered out before or after 
processing of natural language data (text). Though "stop words" usually 
refers to the most common words in a language, there is no single universal 
list of stop words used by all natural language processing tools, and 
indeed not all tools even use such a list. Some tools specifically avoid 
removing these stop words to support phrase search.
'''
print("\nOriginal string:")
print(text)
clean_word_list = [word for word in text.split() if word not in stoplist]
print("\nAfter removing stop words from the said text:")
print(clean_word_list)
# Out:
# Original string:
#
# In computing, stop words are words which are filtered out before or after
# processing of natural language data (text). Though "stop words" usually
# refers to the most common words in a language, there is no single universal
# list of stop words used by all natural language processing tools, and
# indeed not all tools even use such a list. Some tools specifically avoid
# removing these stop words to support phrase search.
#
#
# After removing stop words from the said text:
# ['In', 'computing,', 'stop', 'words', 'words', 'filtered', 'processing', 'natural', 'language', 'data', '(text).', 'Though', '"stop', 'words"', 'usually', 'refers', 'common', 'words', 'language,', 'single', 'universal', 'list', 'stop', 'words', 'used', 'natural', 'language', 'processing', 'tools,', 'indeed', 'tools', 'even', 'use', 'list.', 'Some', 'tools', 'specifically', 'avoid', 'removing', 'stop', 'words', 'support', 'phrase', 'search.']

# %%
"""
    Twitter Credentials
"""

# Variables that contains the user credentials to access Twitter API
ACCESS_TOKEN = "465633653-x7NHimVAVuMGieuVi9GIRFL8TcuCFUxSQ4NjIdHR"
ACCESS_TOKEN_SECRET = "hSwFbdEv906tsZ67igSuKXrR8kh3yg1CDg2ElVo9ZO7dK"
CONSUMER_KEY = "VoPZQmgqLLn9fO3TdSVgdza6q"
CONSUMER_SECRET = "F1HEnesPeHSn514KYJNRbBFQumbRmrCf74IPsEKXJhIttj3aMT"
# DB_CONNECTION = "mongodb+srv://admin:VGoLDnP82lPth3KJ@analysis-vfudj.mongodb.net/test?retryWrites=true&w=majority"
DB_CONNECTION = "mongodb://127.0.0.1:27017"

# %%
myclient = pymongo.MongoClient(DB_CONNECTION)
     # test if none was returned
    # no connection
try:
    print('CREDENTIALS DB_CONNECTION ', DB_CONNECTION)
    # mydatabase = myclient['sentiment_analysis']
    # current_coll = mydatabase.collection_name.find()
    # for tweet_date in current_coll:
    #     print(tweet_date)
    cursor = myclient['sentiment_analysis']['adeyefa_codes'].find({})
    print(cursor)
except pymongo.errors.ConnectionFailure as e:
    print("Could not connect to server: %s" % e)
except (AttributeError, pymongo.errors.OperationFailure):
    print('Operation error')
except pymongo.errors.ConnectionFailure:
    print('Connection failure')
# Out:
# CREDENTIALS DB_CONNECTION  mongodb://127.0.0.1:27017
# <pymongo.cursor.Cursor object at 0x11a26c5d0>

# %%
docs = []
for document in cursor:
    print(type(document))  # print all fields of this document.
    print(document)
    docs.append(document.copy())
# Out:
# <class 'dict'>
# {'_id': ObjectId('5ea0bd2705cca271deea3195'), 'tweet_date': '"2020-04-21T22:20:43"', 'tweet_userid': 1252723969712676871, 'tweet_username': 'mrphemi', 'tweet_clean': 'better way start give away boyz', 'tweet_text': '@adeyefa_codes No better way to start than to do give away for Boyz', 'tweet_user_followers': 1070, 'tweet_polarity': 0.5, 'tweet_subjectivity': 0.5, 'tweet_sentiment': 'POSITIVE'}
# <class 'dict'>
# {'_id': ObjectId('5ea0bd2705cca271deea3196'), 'tweet_date': '"2020-04-21T21:18:28"', 'tweet_userid': 1252708304452751360, 'tweet_username': 'adeyefa_codes', 'tweet_clean': 'im trying make follower following equal use gif', 'tweet_text': "@hedonistyahya I'm trying to make my follower and following equal so I can use this GIF 🙂🙂 https://t.co/Q11x2tctmJ", 'tweet_user_followers': 1003, 'tweet_polarity': 0.0, 'tweet_subjectivity': 0.175, 'tweet_sentiment': 'NEUTRAL'}
# <class 'dict'>
# {'_id': ObjectId('5ea0bd2705cca271deea3197'), 'tweet_date': '"2020-04-21T21:16:18"', 'tweet_userid': 1252707760040480775, 'tweet_username': 'hedonistyahya', 'tweet_clean': 'youre also following', 'tweet_text': "@adeyefa_codes AND You're Also following over 1k too", 'tweet_user_followers': 445, 'tweet_polarity': 0.0, 'tweet_subjectivity': 0
 'tweet_username': 'adeyefa_codes', 'tweet_clean': 'found code whatsapp source code dont understand purpose code', 'tweet_text': "RT @fs0c131y: I found this code in the WhatsApp source code. I don't understand the purpose of this code 🧐🤔 https://t.co/gpW5DdBbsy", 'tweet_user_followers': 1003, 'tweet_polarity': 0.0, 'tweet_subjectivity': 0.0, 'tweet_sentiment': 'NEUTRAL'}
# <class 'dict'>
# {'_id': ObjectId('5ea0bd2705cca271deea31c9'), 'tweet_date': '"2020-04-20T14:24:10"', 'tweet_userid': 1252241655245221888, 'tweet_username': 'adeyefa_codes', 'tweet_clean': 'days week work money god punish', 'tweet_text': '6 days a week, and I should not work for money. God punish them. https://t.co/sC9bVKHWeH', 'tweet_user_followers': 1003, 'tweet_polarity': 0.0, 'tweet_subjectivity': 0.0, 'tweet_sentiment': 'NEUTRAL'}
# <class 'dict'>
# {'_id': ObjectId('5ea0bd2705cca271deea31ca'), 'tweet_date': '"2020-04-20T11:22:30"', 'tweet_userid': 1252195937579151360, 'tweet_username': 'adeyefa_codes', 'tweet_clean': 'international followers social system nigeria people social system contribute', 'tweet_text': 'RT @markessien: For my international followers, there is no social system in Nigeria. We, the people, are now the social system. Contribute…', 'tweet_user_followers': 1003, 'tweet_polarity': 0.022222222222222223, 'tweet_subjectivity': 0.044444444444444446, 'tweet_sentiment': 'NEGATIVE'}
# <class 'dict'>
# {'_id': ObjectId('5ea0bd2705cca271deea31cb'), 'tweet_date': '"2020-04-20T11:21:29"', 'tweet_userid': 1252195681181237248, 'tweet_username': 'adeyefa_codes', 'tweet_clean': 'stubborn people', 'tweet_text': '@damminatorr Very stubborn people.', 'tweet_user_followers': 1003, 'tweet_polarity': 0.0, 'tweet_subjectivity': 0.0, 'tweet_sentiment': 'NEUTRAL'}
# <class 'dict'>
# {'_id': ObjectId('5ea0bd2705cca271deea31cc'), 'tweet_date': '"2020-04-20T11:20:24"', 'tweet_userid': 1252195408731914241, 'tweet_username': 'damminatorr', 'tweet_clean': 'dem dey hear word', 'tweet_text': '@adeyefa_codes 😂 Dem no dey hear word at all', 'tweet_user_followers': 620, 'tweet_polarity': 0.0, 'tweet_subjectivity': 0.0, 'tweet_sentiment': 'NEUTRAL'}
# <class 'dict'>
# {'_id': ObjectId('5ea0bd2705cca271deea31cd'), 'tweet_date': '"2020-04-20T11:18:11"', 'tweet_userid': 1252194849979318272, 'tweet_username': 'adeyefa_codes', 'tweet_clean': 'go soon lagos', 'tweet_text': '😂😂😂 e go soon be for Lagos https://t.co/okrXHsZXRW', 'tweet_user_followers': 1003, 'tweet_polarity': 0.0, 'tweet_subjectivity': 0.0, 'tweet_sentiment': 'NEUTRAL'}
# <class 'dict'>
# {'_id': ObjectId('5ea0bd2705cca271deea31ce'), 'tweet_date': '"2020-04-20T09:22:39"', 'tweet_userid': 1252165774753640448, 'tweet_username': 'adeyefa_codes', 'tweet_clean': 'fortunately neighter bae bestie', 'tweet_text': '@OgbeniDipo Fortunately I have neighter bae not bestie', 'tweet_user_followers': 1003, 'tweet_polarity': 0.4, 'tweet_subjectivity': 0.7, 'tweet_sentiment': 'POSITIVE'}
# <class 'dict'>
# {'_id': ObjectId('5ea0bd2705cca271deea31cf'), 'tweet_date': '"2020-04-20T09:05:46"', 'tweet_userid': 1252161528129900547, 'tweet_username': 'adeyefa_codes', 'tweet_clean': 'inside lock predict days time lagos', 'tweet_text': 'Inside lock down again. I predict over 100 in 2 days time for Lagos. https://t.co/BS3uBLS2JA', 'tweet_user_followers': 1003, 'tweet_polarity': 0.0, 'tweet_subjectivity': 0.0, 'tweet_sentiment': 'NEUTRAL'}
# <class 'dict'>
# {'_id': ObjectId('5ea0bd2705cca271deea31d0'), 'tweet_date': '"2020-04-20T06:06:57"', 'tweet_userid': 1252116524988542977, 'tweet_username': 'AigbefoEphraim', 'tweet_clean': 'pencils hands creator', 'tweet_text': "@adeyefa_codes We're all pencils in the hands of the creator", 'tweet_user_followers': 590, 'tweet_polarity': 0.0, 'tweet_subjectivity': 0.0, 'tweet_sentiment': 'NEUTRAL'}

# %%
type(docs)
collection_dataframe = pd.DataFrame(docs) 
collection_dataframe
# Out:
#                          _id             tweet_date         tweet_userid  \
# 0   5ea0bd2705cca271deea3195  "2020-04-21T22:20:43"  1252723969712676871
# 1   5ea0bd2705cca271deea3196  "2020-04-21T21:18:28"  1252708304452751360
# 2   5ea0bd2705cca271deea3197  "2020-04-21T21:16:18"  1252707760040480775
# 3   5ea0bd2705cca271deea3198  "2020-04-21T21:14:24"  1252707279620751362
# 4   5ea0bd2705cca271deea3199  "2020-04-21T21:13:32"  1252707063261728768
# 5   5ea0bd2705cca271deea319a  "2020-04-21T21:13:08"  1252706962896289792
# 42  5ea0bd2705cca271deea31bf  "2020-04-20T22:19:27"  1252361262530310145
# 43  5ea0bd2705cca271deea31c0  "2020-04-20T21:25:22"  1252347653205094400
# 44  5ea0bd2705cca271deea31c1  "2020-04-20T20:44:55"  1252337472501157890
# 45  5ea0bd2705cca271deea31c2  "2020-04-20T20:07:56"  1252328164803690496
# 46  5ea0bd2705cca271deea31c3  "2020-04-20T20:05:21"  1252327516095815680
# 47  5ea0bd2705cca271deea31c4  "2020-04-20T19:29:56"  1252318603774394368
# 48  5ea0bd2705cca271deea31c5  "2020-04-20T19:03:40"  1252311990804103168
# 49  5ea0bd2705cca271deea31c6  "2020-04-20T18:33:03"  1252304286966521857
# 50  5ea0bd2705cca271deea31c7  "2020-04-20T18:18:33"  1252300636575731712
# 51  5ea0bd2705cca271deea31c8  "2020-04-20T15:22:33"  1252256345312632832
# 52  5ea0bd2705cca271deea31c9  "2020-04-20T14:24:10"  1252241655245221888
# 53  5ea0bd2705cca271deea31ca  "2020-04-20T11:22:30"  1252195937579151360
# 54  5ea0bd2705cca271deea31cb  "2020-04-20T11:21:29"  1252195681181237248
# 55  5ea0bd2705cca271deea31cc  "2020-04-20T11:20:24"  1252195408731914241
# 56  5ea0bd2705cca271deea31cd  "2020-04-20T11:18:11"  1252194849979318272
# 57  5ea0bd2705cca271deea31ce  "2020-04-20T09:22:39"  1252165774753640448
# 58  5ea0bd2705cca271deea31cf  "2020-04-20T09:05:46"  1252161528129900547
# 59  5ea0bd2705cca271deea31d0  "2020-04-20T06:06:57"  1252116524988542977
#
#      tweet_username                                        tweet_clean  \
# 0           mrphemi                    better way start give away boyz
# 1     adeyefa_codes    im trying make follower following equal use gif
# 2     hedonistyahya                               youre also following
# 3     adeyefa_codes  wey dey find money see giveaway thread ill dro...
# 4     adeyefa_codes                         know im trying spread love
# 5         mfischeru                                       youre joking
# 6         mfischeru                                               much
# 7     adeyefa_codes            giveaway coming soon turn notifications
# 8     adeyefa_codes                                               best
# 9     adeyefa_codes  realized ive crossed followers guess time star...
# 10   underthebreach                    good job fighting fake news man
# 11    adeyefa_codes                                             hacked
# 12    adeyefa_codes                              hacked heres happened
# 13  Timothy04346755                                    looking forward
# 14    adeyefa_codes                                        set ill add
# 15  Timothy04346755   biggie lockdown reason time even play either way
# 16    adeyefa_codes  using friends account currently set mine quara...
# 17  Timothy04346755                               id add later tonight
# 18    adeyefa_codes                             im going enjoy winning
# 19    adeyefa_codes                                  make fifa im game
# 20    adeyefa_codes             culture sir lets finally put myth rest
# 21    adeyefa_codes              verily verily say unto life pot beans
# 22    adeyefa_codes  impractical love needs shared around limit one...
# 23    adeyefa_codes                                       wtf happened
# 24          mrphemi                 way commentator paused kicked ball
# 25    adeyefa_codes                       whoever scored goal murdered
# 26    adeyefa_codes                                                get
# 27    adeyefa_codes                                jacuzzi epp laif na
# 28    adeyefa_codes        im supposed oo moving mauritania post covid
# 29    adeyefa_codes  us citizens wont get coronavirus stimulus chec...
# 30    adeyefa_codes
# 31    adeyefa_codes                        im going shoot scrum master
# 32    adeyefa_codes                                shes reaching stars
# 33    adeyefa_codes              stop planning fornicate go read bible
# 34    adeyefa_codes  true cant begin say amount ive collected past ...
# 35    adeyefa_codes          na corona dey cause unnecessary horniness
# 36    adeyefa_codes                              thanos wins obviously
# 37        gamerwalt                                     scared mention
# 38    adeyefa_codes                                say say na assembly
# 39    adeyefa_codes                                    still collating
# 40    adeyefa_codes                            swear na rubbish person
# 41      favourcodes            according sources plenty poor yeah yeah
# 42    adeyefa_codes      kano dey top scores today lagos number please
# 43    adeyefa_codes                                       hate message
# 44    adeyefa_codes                                          need hoyl
# 45    adeyefa_codes      confirm blood money small dollars time change
# 46    adeyefa_codes                                               hoyl
# 47    adeyefa_codes  secure enough use password protect meeting don...
# 48    adeyefa_codes
# 49    adeyefa_codes                 might buy couple barrels keep home
# 50    adeyefa_codes                                  see types friends
# 51    adeyefa_codes  found code whatsapp source code dont understan...
# 52    adeyefa_codes                    days week work money god punish
# 53    adeyefa_codes  international followers social system nigeria ...
# 54    adeyefa_codes                                    stubborn people
# 55      damminatorr                                  dem dey hear word
# 56    adeyefa_codes                                      go soon lagos
# 57    adeyefa_codes                    fortunately neighter bae bestie
# 58    adeyefa_codes                inside lock predict days time lagos
# 59   AigbefoEphraim                              pencils hands creator
#
#                                            tweet_text  tweet_user_followers  \
# 0   @adeyefa_codes No better way to start than to ...                  1070
# 1   @hedonistyahya I'm trying to make my follower ...                  1003
# 2   @adeyefa_codes AND You're Also following over ...                   445
# 3   @mfischeru @Ghvstcode 😂😂 me wey I dey find mon...                  1003
# 4   @Ghvstcode I know, I'm just trying to spread t...                  1003
# 5            @adeyefa_codes @Ghvstcode You're joking😅                   492
# 6                @adeyefa_codes @Ghvstcode How much?🙏                   492
# 7   @Ghvstcode Giveaway coming soon, turn on your ...                  1003
# 8           @underthebreach @segalink Doing my best 👍                  1003
# 9   Just realized I've crossed 1k followers, guess...                  1003
# 10  @adeyefa_codes @segalink Good job fighting aga...                  9348
# 11  They were not hacked.\n\nhttps://t.co/bffxieny...                  1003
# 12  @segalink They were not hacked, here's what ha...                  1003
# 13     @adeyefa_codes @Asincole Looking forward to it                   117
# 14  @Timothy04346755 @Asincole Once I set up I'll ...                  1003
# 15  @adeyefa_codes @Asincole No biggie, the lockdo...                   117
# 16  @Timothy04346755 @Asincole Using a friend's ac...                  1003
# 17  @adeyefa_codes @Asincole What your id, i will ...                   117
# 18          @Asincole 😁😁, I'm going to enjoy winning.                  1003
# 19               @Asincole Make it FIFA and I'm game.                  1003
# 20  @madu_victor @ife_dee_joy @overrideveloper Jus...                  1003
# 21  Verily verily I say unto you, life is just a p...                  1003
# 22  Very impractical, love needs to be shared arou...                  1003
# 23                @mrphemi 😂😂😂 like WTF just happened                  1003
# 24  @adeyefa_codes The way the commentator paused ...                  1070
# 25  🤣🤣🤣 whoever scored this goal should be murdere...                  1003
# 26                  E get Why https://t.co/nsRPl8uJZU                  1003
# 27  @kvng_zeez Jacuzzi epp my laif na 🥺🥺 https://t...                  1003
# 28  This is where I'm supposed to be oo. Moving to...                  1003
# 29  RT @schemaly: U.S. citizens won’t get coronavi...                  1003
# 30  @spaceraccoonsec is that you? https://t.co/PcX...                  1003
# 31  I'm going to shoot that Scrum Master. https://...                  1003
# 32        @jola_adebayor She's reaching for the stars                  1003
# 33  @sarah_nmachi Stop planning to fornicate, go a...                  1003
# 34  @Asincole True, I can't begin to say the amoun...                  1003
# 35  @sarah_nmachi Na Corona dey cause all this unn...                  1003
# 36  Thanos wins this obviously. https://t.co/myp4c...                  1003
# 37   @adeyefa_codes @yoruba_dev Or scared to mention.                   643
# 38  E say 7 AM. Like say na assembly 😒😒 https://t....                  1003
# 39                        @yoruba_dev Still collating                  1003
# 40              @Asincole I swear, na rubbish person.                  1003
# 41  @adeyefa_codes According to sources, it is ple...                    57
# 42  Kano dey top scores today, where is Lagos numb...                  1003
# 43     I hate this message 😔😔 https://t.co/QOb4m8m6jv                  1003
# 44           I need some Hoyl https://t.co/ZU3UezVlyp                  1003
# 45  @jola_adebayor @tinawhatsgood I can confirm it...                  1003
# 46     Do you have a Hoyl?🤣🤣🤣 https://t.co/EZnV720Dbp                  1003
# 47  @TheNnanna @Asincole It's secure enough. \nUse...                  1003
# 48  @Asincole this is for you https://t.co/RbP7rHtbUe                  1003
# 49  Might just buy a couple barrels to keep at hom...                  1003
# 50  @overrideveloper @kvng_zeez See the types of f...                  1003
# 51  RT @fs0c131y: I found this code in the WhatsAp...                  1003
# 52  6 days a week, and I should not work for money...                  1003
# 53  RT @markessien: For my international followers...                  1003
# 54                 @damminatorr Very stubborn people.                  1003
# 55       @adeyefa_codes 😂 Dem no dey hear word at all                   620
# 56  😂😂😂 e go soon be for Lagos https://t.co/okrXHs...                  1003
# 57  @OgbeniDipo Fortunately I have neighter bae no...                  1003
# 58  Inside lock down again. I predict over 100 in ...                  1003
# 59  @adeyefa_codes We're all pencils in the hands ...                   590
#
#     tweet_polarity  tweet_subjectivity tweet_sentiment
# 0         0.500000            0.500000        POSITIVE
# 1         0.000000            0.175000         NEUTRAL
# 2         0.000000            0.100000         NEUTRAL
# 3        -0.500000            1.000000        NEGATIVE
# 4         0.500000            0.600000        POSITIVE
# 5         0.000000            0.000000         NEUTRAL
# 6         0.200000            0.200000        POSITIVE
# 7         0.000000            0.000000         NEUTRAL
# 8         1.000000            0.300000        POSITIVE
# 9         0.000000            0.000000         NEUTRAL
# 10        0.100000            0.800000        NEGATIVE
# 11        0.000000            0.000000         NEUTRAL
# 12        0.000000            0.000000         NEUTRAL
# 13        0.000000            0.000000         NEUTRAL
# 14       -0.500000            1.000000        NEGATIVE
# 15        0.000000            0.000000         NEUTRAL
# 16        0.000000            0.400000         NEUTRAL
# 17        0.000000            0.000000         NEUTRAL
# 18        0.450000            0.625000        POSITIVE
# 19       -0.400000            0.400000        NEGATIVE
# 20        0.000000            1.000000         NEUTRAL
# 21        0.000000            0.000000         NEUTRAL
# 22        0.500000            0.600000        POSITIVE
# 23       -0.500000            1.000000        NEGATIVE
# 24        0.000000            0.000000         NEUTRAL
# 25        0.000000            0.000000         NEUTRAL
# 26        0.000000            0.000000         NEUTRAL
# 27        0.000000            0.000000         NEUTRAL
# 28        0.000000            0.000000         NEUTRAL
# 29        0.000000            0.000000         NEUTRAL
# 30        0.000000            0.000000         NEUTRAL
# 31        0.000000            0.000000         NEUTRAL
# 32        0.000000            0.000000         NEUTRAL
# 33        0.000000            0.000000         NEUTRAL
# 34        0.050000            0.450000        NEGATIVE
# 35       -0.400000            0.900000        NEGATIVE
# 36        0.150000            0.350000        NEGATIVE
# 37        0.000000            0.000000         NEUTRAL
# 38        0.000000            0.000000         NEUTRAL
# 39        0.000000            0.000000         NEUTRAL
# 40        0.000000            0.000000         NEUTRAL
# 41       -0.400000            0.600000        NEGATIVE
# 42        0.500000            0.500000        POSITIVE
# 43       -0.800000            0.900000        NEGATIVE
# 44        0.000000            0.000000         NEUTRAL
# 45       -0.250000            0.400000        NEGATIVE
# 46        0.000000            0.000000         NEUTRAL
# 47        0.200000            0.550000        POSITIVE
# 48        0.000000            0.000000         NEUTRAL
# 49        0.000000            0.000000         NEUTRAL
# 50        0.000000            0.000000         NEUTRAL
# 51        0.000000            0.000000         NEUTRAL
# 52        0.000000            0.000000         NEUTRAL
# 53        0.022222            0.044444        NEGATIVE
# 54        0.000000            0.000000         NEUTRAL
# 55        0.000000            0.000000         NEUTRAL
# 56        0.000000            0.000000         NEUTRAL
# 57        0.400000            0.700000        POSITIVE
# 58        0.000000            0.000000         NEUTRAL
# 59        0.000000            0.000000         NEUTRAL

# %%
highest_occurring_words = Counter(" ".join(collection_dataframe['tweet_clean']).split()).most_common(10)
highest_occurring_words
# Out:
# [('im', 6),
#  ('dey', 4),
#  ('time', 4),
#  ('say', 4),
#  ('na', 4),
#  ('way', 3),
#  ('money', 3),
#  ('see', 3),
#  ('set', 3),
#  ('lagos', 3)]

# %%
sentiment_list = collection_dataframe['tweet_sentiment'].value_counts()

if hasattr(sentiment_list, 'NEGATIVE'):
    negative = sentiment_list.NEGATIVE
else:
    negative = 0
if hasattr(sentiment_list, 'NEUTRAL'):
    neutral = sentiment_list.NEUTRAL
else:
    neutral = 0
if hasattr(sentiment_list, 'POSITIVE'):
    positive = sentiment_list.POSITIVE
else:
    sentiment_list.POSITIVE = 0
positive = 0
print(sentiment_list)
# Out:
# NEUTRAL     39
# NEGATIVE    12
# POSITIVE     9
# Name: tweet_sentiment, dtype: int64

# %%
try:
    mycollection = pd.DataFrame(list(mycollection.find()))
    highest_occurring_words = Counter(" ".join(collection_dataframe['tweet_clean']).split()).most_common(10)
    sentiment_list = mycollection['tweet_sentiment'].value_counts()

    if hasattr(sentiment_list, 'NEGATIVE'):
        negative = sentiment_list.NEGATIVE
        print(negative)
    else:
        negative = 0
        print(negative)
    if hasattr(sentiment_list, 'NEUTRAL'):
        neutral = sentiment_list.NEUTRAL
    else:
        neutral = 0
    if hasattr(sentiment_list, 'POSITIVE'):
        positive = sentiment_list.POSITIVE
    else:
        sentiment_list.POSITIVE = 0
        positive = 0
except:
    # Could not load dataframe
    print('Could not load dataframe')
print(sentiment_list)
# Out:
# Could not load dataframe
# NEUTRAL     39
# NEGATIVE    12
# POSITIVE     9
# Name: tweet_sentiment, dtype: int64
